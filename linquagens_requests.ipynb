# %% [markdown]
# # Conhecendo a requests

# %% [markdown]
# ## Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ## Explorando o response

# %%
r.text
# Out:
# '[{"id":"43457078981","type":"IssueCommentEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":466728580,"name":"jfrog/frogbot","url":"https://api.github.com/repos/jfrog/frogbot"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/jfrog/frogbot/issues/778","repository_url":"https://api.github.com/repos/jfrog/frogbot","labels_url":"https://api.github.com/repos/jfrog/frogbot/issues/778/labels{/name}","comments_url":"https://api.github.com/repos/jfrog/frogbot/issues/778/comments","events_url":"https://api.github.com/repos/jfrog/frogbot/issues/778/events","html_url":"https://github.com/jfrog/frogbot/pull/778","id":2624363761,"node_id":"PR_kwDOG9G2hM6AZfPY","number":778,"title":"Add option to skip comment generation on PR success","user":{"login":"attiasas","id":49212512,"nod
# ...

# %%
r.json()
# Out:
# [{'id': '43457078981',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 466728580,
#    'name': 'jfrog/frogbot',
#    'url': 'https://api.github.com/repos/jfrog/frogbot'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/jfrog/frogbot/issues/778',
#     'repository_url': 'https://api.github.com/repos/jfrog/frogbot',
#     'labels_url': 'https://api.github.com/repos/jfrog/frogbot/issues/778/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/jfrog/frogbot/issues/778/comments',
#     'events_url': 'https://api.github.com/repos/jfrog/frogbot/issues/778/events',
#     'html_url': 'https://github.com/jfrog/frogbot/pull/778',
#     'id': 2624363761,
# ...

# %% [markdown]
# ### Usando outr endpoint

# %%
r = requests.get('https://api.github.com/versions')

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ### adicionando headers

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

r = requests.get('https://api.github.com/events', headers=headers)

r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'id': '43457078981',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 466728580,
#    'name': 'jfrog/frogbot',
#    'url': 'https://api.github.com/repos/jfrog/frogbot'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/jfrog/frogbot/issues/778',
#     'repository_url': 'https://api.github.com/repos/jfrog/frogbot',
#     'labels_url': 'https://api.github.com/repos/jfrog/frogbot/issues/778/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/jfrog/frogbot/issues/778/comments',
#     'events_url': 'https://api.github.com/repos/jfrog/frogbot/issues/778/events',
#     'html_url': 'https://github.com/jfrog/frogbot/pull/778',
#     'id': 2624363761,
# ...

# %%
username = 'edilvolima'
r = requests.get(f'https://api.github.com/users/{username}')

r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'login': 'edilvolima',
#  'id': 3931395,
#  'node_id': 'MDQ6VXNlcjM5MzEzOTU=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/3931395?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/edilvolima',
#  'html_url': 'https://github.com/edilvolima',
#  'followers_url': 'https://api.github.com/users/edilvolima/followers',
#  'following_url': 'https://api.github.com/users/edilvolima/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/edilvolima/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/edilvolima/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/edilvolima/subscriptions',
#  'organizations_url': 'https://api.github.com/users/edilvolima/orgs',
#  'repos_url': 'https://api.github.com/users/edilvolima/repos',
#  'events_url': 'https://api.github.com/users/edilvolima/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/edilvolima/received_events',
#  'type': 'User',
# ...

# %%
r.text
# Out:
# '{"login":"edilvolima","id":3931395,"node_id":"MDQ6VXNlcjM5MzEzOTU=","avatar_url":"https://avatars.githubusercontent.com/u/3931395?v=4","gravatar_id":"","url":"https://api.github.com/users/edilvolima","html_url":"https://github.com/edilvolima","followers_url":"https://api.github.com/users/edilvolima/followers","following_url":"https://api.github.com/users/edilvolima/following{/other_user}","gists_url":"https://api.github.com/users/edilvolima/gists{/gist_id}","starred_url":"https://api.github.com/users/edilvolima/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/edilvolima/subscriptions","organizations_url":"https://api.github.com/users/edilvolima/orgs","repos_url":"https://api.github.com/users/edilvolima/repos","events_url":"https://api.github.com/users/edilvolima/events{/privacy}","received_events_url":"https://api.github.com/users/edilvolima/received_events","type":"User","user_view_type":"public","site_admin":false,"name":"Edilvo Lima","company":null,"blog"
# ...

# %%
r.url
# Out:
# 'https://api.github.com/users/edilvolima'

# %%
r.json()['name']
# Out:
# 'Edilvo Lima'

# %%
r.json()['created_at']
# Out:
# '2013-03-21T13:16:50Z'

# %% [markdown]
# # Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ## Autenticação

# %%
# Local onde o token está armazenado
import request_token

# %%
access_token = request_token.REQUESTS_TOKEN
headers = {'Authorization': 'Bearer ' + access_token, 
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# ## Paginando os repositórios
